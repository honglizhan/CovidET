# %%
import pandas as pd
test_df = pd.read_json("./data/final-Turkers-1487.json", orient="index")

# %%
test_df.head()
# Out:
#   Reddit ID     Time Created  \
# 0    ort1np   7/26/2021 6:27
# 1    orvzru  7/26/2021 10:28
# 2    orzgjg  7/26/2021 14:08
# 3    os1kcg  7/26/2021 15:52
# 4    os2nb8  7/26/2021 16:43
#
#                                          Reddit Post  \
# 0  Im suppose to get my first vaccination soon. E...
# 1  Hi. My mom is already fully vaccinated (with S...
# 2  My husband tested positive last week despite b...
# 3  Ive been fully vaccinated since mid April. I w...
# 4  I had a pcr test sent to me after requesting i...
#
#                                          Annotations
# 0  {'Annotation 0 | Assignment ID = 3VAR3R6G1Q0PX...
# 1  {'Annotation 0 | Assignment ID = 3VAR3R6G1Q0PX...
# 2  {'Annotation 0 | Assignment ID = 3WLEIWSYHPG4J...
# 3  {'Annotation 0 | Assignment ID = 3WLEIWSYHPG4J...
# 4  {'Annotation 0 | Assignment ID = 3VNXK88KKDHK1...

# %%
train_ex = pd.read_json("./data/train_dev_test/anger/training.json")

# %%
train_ex
# Out:
#                                              positives  \
# 0    my mom works at a hospital so since the pandem...
# 1    Why do people still have hope this will ever e...
# 2    So last night I got stood up by an online date...
# 3    I apologize beforehand as these links are in S...
# 4    reference: [url] only 77% effective against ho...
# ..                                                 ...
# 367  I'm not kidding. Idk how much more of this f@\...
# 368  Anyone here stressed about the potential need ...
# 369  My mother has just gone insane. No matter what...
# 370  anyone else at the point of clawing their scre...
# 371  Just a daily concern of mine in relation to th...
#
#                                              negatives
# 0    So I live in the US, and as you know we have l...
# 1    Hey yall. Has anybody seen any difference betw...
# 2    The majority of my friends are around my age (...
# 3    So recently both my parents tested positive fo...
# ...
